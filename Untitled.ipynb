# %%
import pandas as pd

# %%
df = pd.read_csv('dataset_vivienda.csv')

# %%
print(df.describe())
# Out:
#              precio        area  habitaciones  antiguedad
# count  6.570000e+02  657.000000    657.000000  657.000000
# mean   1.899074e+08  111.563166      2.637747   24.484018
# std    6.241747e+07   42.701810      1.329648   14.496429
# min    2.014238e+07   30.000000      1.000000    0.000000
# 25%    1.538308e+08   77.000000      1.000000   12.000000
# 50%    1.912871e+08  112.000000      3.000000   23.000000
# 75%    2.315562e+08  143.000000      4.000000   36.000000
# max    3.500000e+08  245.000000      5.000000   50.000000

# %%
print(df.head())
# Out:
#       precio  area  habitaciones  antiguedad fecha_publicacion  \
# 0  249900595   124             1          13         8/29/2022
# 1  106755036    77             4          20         3/21/2025
# 2  241100010    44             1          47         4/15/2021
# 3  177521863    69             1          19         3/12/2023
# 4  205299516   111             2           7         1/20/2023
#
#              descripcion
# 0        Casa remodelada
# 1        Casa remodelada
# 2   Apartamento céntrico
# 3  Apartamento económico
# 4         Casa espaciosa
